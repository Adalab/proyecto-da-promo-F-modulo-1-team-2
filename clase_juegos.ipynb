# %%
import random

class Juegos:
    def ahorcado(self):
        print("""
            - BIENVENIDO AL JUEGO DEL AHORCADO. 
            - Hemos cogido a la segunda mejor persona del mundo, no íbamos a coger a la mejor, ¡¡¡no somos unos monstruos!!!
            - Seguro que conoces este juego, pero por si acaso te cuento: consiste en adivinar una palabra para salvar la vida de nuestra víctima. 
            - Se necesitan dos jugadores. Uno de vosotros introduce la palabra y otro adivina. 
            - Para averiguar la palabra, el jugador encargado de adivinar, irá introduciendo letras.
            - Si la letra no se encuentra en la palabra a adivinar se considera fallo y se reflejará en el dibujo. ¡Sálvale! 
            - Tienes un total de 7 intentos.
        """)

        contador7 ="""
              _______
             |/      |
             |      (_)
             |      \|/
             |       |
             |      / \\
             |
            _|___   """

        contador6 ="""
              _______
             |/      |
             |      (_)
             |      \|/
             |       |
             |      / 
             |
            _|___   """

        contador5 ="""
              _______
             |/      |
             |      (_)
             |      \|/
             |       |
             |      
             |
            _|___   """

        contador4 ="""
              _______
             |/      |
             |      (_)
             |      \|
             |       |
             |       
             |
            _|___   """

        contador3 ="""
              _______
             |/      |
             |      (_)
             |       |
             |       |
             |       
             |
            _|___   """

        contador2 ="""
              _______
             |/      |
             |      (_)
             |       
             |       
             |       
             |
            _|___   """

        contador1 ="""
              _______
             |/      |
             |      
             |       
             |       
             |       
             |
            _|___   """

        contador0 ="""
              _______
             |/      
             |      
             |       
             |       
             |       
             |
            _|___   """

        contador = 0
        lista_contador = [contador0,contador1,contador2,contador3,contador4,contador5,contador6,contador7]
        palabra = input("Introduce una palabra para que sea adivinada").lower()
        #palabra = "agua"
        palabraadivinada = "_" * len(palabra)
        #print(palabraadivinada)
        listapalabraadivinada = list(palabraadivinada)
        listapalabra = list(palabra)
        listaletras = []
        #print("".join(listapalabra))
        print(" ".join(listapalabraadivinada))
        print(lista_contador[contador])

        while listapalabra != listapalabraadivinada:
            letra = input("Elige una letra").lower()
            if letra in listapalabra:
                for i in range(len(listapalabra)):
                    if letra == listapalabra[i]:
                        listapalabraadivinada[i] = letra
                print(f"La {letra} está en la palabra", "\N{winking face}")
                print(lista_contador[contador])
                
            else:
                print(f"Te equivocaste, la letra {letra} no está en la palabra", "\N{face with peeking eye}")
                contador += 1
                print(lista_contador[contador])
                if contador == 7:
                    break

            print(" ".join(listapalabraadivinada))
            listaletras.append(letra)
            listaletras.sort()
            print(f"Las letras usadas {listaletras}")

        if contador == 7:
            print("¡¡¡Has perdido!!! \N{crying face}")
            print("""
                                                            
        88                                              
        88                                              
        88                                              
        88  ,adPPYba,  ,adPPYba,  ,adPPYba, 8b,dPPYba,  
        88 a8"     "8a I8[    "" a8P_____88 88P'   "Y8  
        88 8b       d8  `"Y8ba,  8PP""""""" 88          
        88 "8a,   ,a8" aa    ]8I "8b,   ,aa 88          
        88  `"YbbdP"'  `"YbbdP"'  `"Ybbd8"' 88 """)
        else: 
            print("¡¡¡HAS GANADO!!!")
            
            #añadir print ahorcado tambien añadir cuando el jugador gana

#---------------------------------------------------------------------------------------
    def piedrapapeltijera(self):
        print("""
            - BIENVENIDO AL JUEGO DE PIEDRA, PAPEL O TIJERA. 
            - Vas a jugar contra mí, ¡mua ha ha haaaa!
            - Solo tienes que elegir una de estas tres opciones: piedra, papel o tijera.
            Recuerda: piedra aplasta a tijera, papel envuelve a piedra y tijera corta a papel.
            - Quien gane tres veces gana la partida. ¡Suerte! Las vas a necesitar ¡mua ha ha haaaa!
        """)

        puntos_jugador = 0
        puntos_pc = 0
        # Añadir reglas del juego y añadir contadores visibles (yo llevo tanto y tú tanto)

        while puntos_jugador < 3 and puntos_pc < 3:
            opciones = ['piedra','papel','tijera']

            tu_eleccion = input("Escribe que quieres: piedra, papel o tijera.").lower()
            while tu_eleccion not in opciones:
                print("No has introducido ninguna opción de las dadas.")
                tu_eleccion = input("¿Qué quieres: piedra, papel o tijera.?").lower()

            pc_eleccion = opciones[random.randint(0,2)] 
            # Elección al azar del ordenador usando los índices para acceder a la lista de cartas.
            
            print(f"\t\tMi elección es:{pc_eleccion}")
            print(f"\t\tTu elección es:{tu_eleccion}")

            # Sacamos los índices de la elección del usuario y la del ordenador.
            indice_tu_palabra = opciones.index(tu_eleccion)
            indice_pc_palabra = opciones.index(pc_eleccion)

            # Comenzamos las comparaciones
            if indice_tu_palabra == 0 and indice_pc_palabra == 2: # Piedra gana a papel aunque es 0 y 2
                puntos_jugador += 1
                print(f"""\nA ver... {tu_eleccion} gana a {pc_eleccion}\n
                    ¡ME HAS GANADO!""", "\N{confounded face}\n")    
            else:
                if indice_tu_palabra < indice_pc_palabra:
                    puntos_pc += 1
                    print(f"""\nA ver... {pc_eleccion} gana a {tu_eleccion}\n
                        ¡TE HE GANADO!""","\N{relieved face}\n")
                elif indice_tu_palabra > indice_pc_palabra:
                    puntos_jugador += 1
                    print(f"""\nA ver... {tu_eleccion} gana a {pc_eleccion}\n
                        ¡ME HAS GANADO!""","\N{confounded face}\n")
                else:
                    print("\n\t\tIguales, empatamos \N{neutral face} \n")
            if puntos_pc == puntos_jugador == 2:
                print("\t\tEstamos empatados. ¡¡¡Quien acierte gana el juego!!!\N{melting face}\n")
        if puntos_pc == 3:
            print("\n¡HE GANADO EL JUEGO!")
        else:
            print("\n¡ENHORABUENA! ¡HAS GANADO EL JUEGO!\n")
            print("""
                                                            
        {}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}
        {} ___ ___  _______  _______      _______  ______  _______      _______ {}
        {}|   |   ||       ||   |   |    |   _   ||   __ \|    ___|    |   _   |{}
        {} \     / |   -   ||   |   |    |       ||      <|    ___|    |       |{}
        {}  |___|  |_______||_______|    |___|___||___|__||_______|    |___|___|{}
        {}                                                                      {}
        {} ________  _______  _______  _______  _______  ______                 {}
        {}|  |  |  ||_     _||    |  ||    |  ||    ___||   __ \                {}
        {}|  |  |  | _|   |_ |       ||       ||    ___||      <                {}
        {}|________||_______||__|____||__|____||_______||___|__|                {}
        {}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}{}""")

        print("Bye, bye, my friend! \N{crying face}")
#---------------------------------------------------------------------------------------
    def preguntas_respuestas(self):

        print("""
            - BIENVENIDO AL JUEGO DE PREGUNTAS Y RESPUESTAS. 
            - Vas a jugar contra mí, ¡mua ha ha haaaa!
            - Solo tienes que responder a las preguntas que te haré sobre Europa con una sola palabra y sin usar tildes.
            - Si aciertas 5 preguntas ganarás, pero si fallas 3 perderás ¡Jajajjajaajaj!
            - Como soy majísime te doy dos intentos por pregunta.
            - Buena suerte que la necesitarás.
            """)
        #Creamos el diccionario (FALTAN AÑADIR PREGUNTAS)
        preguntas_respuestas = {"¿Cuál es la capital de Bélgica?":"BRUSELAS", 
                                "¿Qué país de Europa limita con más países?":"RUSIA", 
                                "¿En qué país están los Apeninos?":"ITALIA", 
                                "¿Cuál es la capital de los Países Bajos?": "AMSTERDAM", 
                                "¿Cómo se llama el pico más alto de Europa?": "ELBRUS", 
                                "¿Qué río europeo fluye a través de 10 países diferentes?":"DANUBIO", 
                                "¿Cuál es el país europeo más pequeño?":"VATICANO", 
                                "¿Cuál es la ciudad más poblada de Europa?":"ESTAMBUL",
                                "¿Cuál es la cordillera más alta de Europa?":"CAUCASO",
                                "¿Cuál es el país más al norte de Europa?": "NORUEGA",
                                "¿Qué río pasa por París?":"SENA",
                                "¿Cuál es la capital de Austria?":"VIENA",
                                "¿Los Pirineos son frontera natural entre Francia, España y…?":"ANDORRA",
                                "¿A qué país pertenece Cracovia?":"POLONIA",
                                "¿En qué provincia está Sierra Nevada?":"GRANADA",
                                "¿Cuál es el río más largo de Europa?":"VOLGA",
                                "¿Cuál es la capital de Francia?":"PARIS",
                                "El estrecho que separa Europa de África el de...":"GIBRALTAR"}

        print("¡Empezamos!")
        puntos_positivos=0
        puntos_negativos=0
        
        while puntos_positivos<5 and puntos_negativos<3:
            intentos = 0

            pregunta, respuesta = random.choice(list(preguntas_respuestas.items())) 
            # Mete en la variable pregunta el valor de una key y su value en la variable respuesta

            print(pregunta)

            respuesta_usuario = input().upper()
            while intentos < 2:
                if respuesta_usuario == respuesta:
                    puntos_positivos += 1
                    print("¡CORRECTO! \N{winking face}")
                    intentos = 2
                
                elif intentos == 0:
                    intentos += 1
                    print("¡ERROR! Te queda un intento \N{melting face}")
                    respuesta_usuario = input().upper()

                else: 
                    intentos += 1
                    puntos_negativos += 1
                    print(f"¡Has vuelto a fallar! La solución era {respuesta}.", "\N{face with peeking eye}")
            print(f"Llevas {puntos_positivos} respuestas correctas y {puntos_negativos} respuestas incorrectas")
            
            preguntas_respuestas.pop(pregunta)
        if puntos_positivos == 5:
            print("¡Enhorabuena! ¡Has ganado! \N{grinning face with smiling eyes}")
            print("""
    >>============================================<<
    ||O))      O))    O))))     O))     O))       ||
    || O))    O))   O))    O))  O))     O))       ||
    ||  O)) O))   O))        O))O))     O))       ||
    ||    O))     O))        O))O))     O))       ||
    ||    O))     O))        O))O))     O))       ||
    ||    O))       O))     O)) O))     O))       ||
    ||    O))         O))))       O)))))          ||
    ||                                            ||
    ||      O)       O)))))))    O))))))))        ||
    ||     O) ))     O))    O))  O))              ||
    ||    O)  O))    O))    O))  O))              ||
    ||   O))   O))   O) O))      O))))))          ||
    ||  O)))))) O))  O))  O))    O))              ||
    || O))       O)) O))    O))  O))              ||
    ||O))         O))O))      O))O))))))))        ||
    ||                                            ||
    ||O))) O))))))O))     O))O))))))))            ||
    ||     O))    O))     O))O))                  ||
    ||     O))    O))     O))O))                  ||
    ||     O))    O)))))) O))O))))))              ||
    ||     O))    O))     O))O))                  ||
    ||     O))    O))     O))O))                  ||
    ||     O))    O))     O))O))))))))            ||
    ||                                            ||
    ||O)) O))       O))))       O)) O)    O)) O)  ||
    ||O)    O))   O))    O))  O))    O))O))    O))||
    ||O)     O))O))        O)) O))       O))      ||
    ||O))) O)   O))        O))   O))       O))    ||
    ||O)     O))O))        O))      O))       O)) ||
    ||O)      O)  O))     O)) O))    O))O))    O))||
    ||O)))) O))     O))))       O)) O)    O)) O)  ||
    >>============================================<<              
    """)
        else:
            print("Ooooohhhh! ¡Has perdido! \N{crying face}")
            print("""┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼
    ███▀▀▀██┼███▀▀▀███┼███▀█▄█▀███┼██▀▀▀
    ██┼┼┼┼██┼██┼┼┼┼┼██┼██┼┼┼█┼┼┼██┼██┼┼┼
    ██┼┼┼▄▄▄┼██▄▄▄▄▄██┼██┼┼┼▀┼┼┼██┼██▀▀▀
    ██┼┼┼┼██┼██┼┼┼┼┼██┼██┼┼┼┼┼┼┼██┼██┼┼┼
    ███▄▄▄██┼██┼┼┼┼┼██┼██┼┼┼┼┼┼┼██┼██▄▄▄
    ┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼
    ███▀▀▀███┼▀███┼┼██▀┼██▀▀▀┼██▀▀▀▀██▄┼
    ██┼┼┼┼┼██┼┼┼██┼┼██┼┼██┼┼┼┼██┼┼┼┼┼██┼
    ██┼┼┼┼┼██┼┼┼██┼┼██┼┼██▀▀▀┼██▄▄▄▄▄▀▀┼
    ██┼┼┼┼┼██┼┼┼██┼┼█▀┼┼██┼┼┼┼██┼┼┼┼┼██┼
    ███▄▄▄███┼┼┼─▀█▀┼┼─┼██▄▄▄┼██┼┼┼┼┼██▄
    ┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼
    ┼┼┼┼┼┼┼┼██┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼██┼┼┼┼┼┼┼┼┼
    ┼┼┼┼┼┼████▄┼┼┼▄▄▄▄▄▄▄┼┼┼▄████┼┼┼┼┼┼┼
    ┼┼┼┼┼┼┼┼┼▀▀█▄█████████▄█▀▀┼┼┼┼┼┼┼┼┼┼
    ┼┼┼┼┼┼┼┼┼┼┼█████████████┼┼┼┼┼┼┼┼┼┼┼┼
    ┼┼┼┼┼┼┼┼┼┼┼██▀▀▀███▀▀▀██┼┼┼┼┼┼┼┼┼┼┼┼
    ┼┼┼┼┼┼┼┼┼┼┼██┼┼┼███┼┼┼██┼┼┼┼┼┼┼┼┼┼┼┼
    ┼┼┼┼┼┼┼┼┼┼┼█████▀▄▀█████┼┼┼┼┼┼┼┼┼┼┼┼
    ┼┼┼┼┼┼┼┼┼┼┼┼███████████┼┼┼┼┼┼┼┼┼┼┼┼┼
    ┼┼┼┼┼┼┼┼▄▄▄██┼┼█▀█▀█┼┼██▄▄▄┼┼┼┼┼┼┼┼┼
    ┼┼┼┼┼┼┼┼▀▀██┼┼┼┼┼┼┼┼┼┼┼██▀▀┼┼┼┼┼┼┼┼┼
    ┼┼┼┼┼┼┼┼┼┼▀▀┼┼┼┼┼┼┼┼┼┼┼▀▀┼┼┼┼┼┼┼┼┼┼┼
    ┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼┼

    """)


partida = Juegos()

# %%
juego = int(input("""Si te apetece jugar a: 
                  piedra, papel o tijera pulsa 1 
                  ahorcado pulsa 2 
                  preguntas y respuestas pulsa 3."""))
if juego == 1:
    partida.piedrapapeltijera()

elif juego == 2:
    partida.ahorcado()

elif juego == 3:
    partida.preguntas_respuestas()

else:
    print("No has introducido un número válido.")
# Out:
#             - BIENVENIDO AL JUEGO DE PREGUNTAS Y RESPUESTAS.
#             - Vas a jugar contra mí, ¡mua ha ha haaaa!
#             - Solo tienes que responder a las preguntas que te haré sobre Europa con una sola palabra y sin usar tildes.
#             - Si aciertas 5 preguntas ganarás, pero si fallas 3 perderás ¡Jajajjajaajaj!
#             - Como soy majísime te doy dos intentos por pregunta.
#             - Buena suerte que la necesitarás.
#
# ¡Empezamos!
# ¿Cuál es la capital de Francia?
# ¡ERROR! Te queda un intento 🫠
# ¡CORRECTO! 😉
# Llevas 1 respuestas correctas y 0 respuestas incorrectas
# ¿Cuál es la capital de los Países Bajos?
# ¡ERROR! Te queda un intento 🫠
# ¡CORRECTO! 😉
# Llevas 2 respuestas correctas y 0 respuestas incorrectas
# ¿Cuál es el país europeo más pequeño?
# ¡CORRECTO! 😉
# Llevas 3 respuestas correctas y 0 respuestas incorrectas
# ¿Cuál es la ciudad más poblada de Europa?
# ¡CORRECTO! 😉
# Llevas 4 respuestas correctas y 0 respuestas incorrectas
# ...
